# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as pit

# %%
df=pd.read_csv('datos_properati_limpios.csv')

# %%
df
# Out:
#        created_on operation property_type  \
# 0      2017-09-22      sell         house
# 1      2017-08-01      sell         store
# 2      2017-08-02      sell         store
# 3      2017-08-03      sell         store
# 4      2017-08-08      sell         store
# 5      2017-08-09      sell         store
# 6      2017-08-11      sell         store
# 7      2017-08-11      sell         store
# 8      2017-08-12      sell         store
# 9      2017-08-15      sell         store
# 10     2017-08-15      sell         store
# 11     2017-08-16      sell         store
# 12     2017-08-16      sell         store
# 13     2017-08-18      sell         store
# 14     2017-08-26      sell         store
# 15     2017-08-26      sell         store
# 16     2017-08-29      sell         store
# 17     2017-08-29      sell         store
# 18     2017-08-29      sell     apartment
# 19     2017-08-29      sell     apartment
# 20     2017-08-29      sell     apartment
# 21     2017-08-30      sell         store
# 22     2017-08-30      sell         house
# 23     2017-08-30      sell         store
# 24     2017-08-30      sell     apartment
# 25     2017-08-30      sell            PH
# 26     2017-08-30      sell     apartment
# 27     2017-08-30      sell         house
# 28     2017-08-30      sell         house
# 29     2017-08-30      sell     apartment
# ...           ...       ...           ...
# 18949  2018-01-26      sell     apartment
# 18950  2018-01-26      sell            PH
# 18951  2018-01-26      sell         store
# 18952  2018-01-26      sell         house
# 18953  2018-01-26      sell            PH
# 18954  2018-01-26      sell            PH
# 18955  2018-01-26      sell     apartment
# 18956  2018-01-26      sell     apartment
# 18957  2018-01-27      sell            PH
# 18958  2018-01-28      sell     apartment
# 18959  2018-01-29      sell            PH
# 18960  2018-01-31      sell     apartment
# 18961  2018-01-31      sell         house
# 18962  2018-01-31      sell            PH
# 18963  2017-09-22      sell     apartment
# 18964  2017-09-30      sell     apartment
# 18965  2017-10-17      sell         house
# 18966  2017-10-17      sell         house
# 18967  2017-10-17      sell            PH
# 18968  2017-10-21      sell     apartment
# 18969  2017-10-21      sell         house
# 18970  2017-10-29      sell     apartment
# 18971  2017-10-29      sell     apartment
# 18972  2017-11-23      sell     apartment
# 18973  2017-12-17      sell     apartment
# 18974  2018-01-08      sell     apartment
# 18975  2018-01-23      sell         house
# 18976  2018-01-24      sell         store
# 18977  2018-01-27      sell     apartment
# 18978  2018-01-27      sell     apartment
#
#                                  place_with_parent_names  \
# 0      |Argentina|Capital Federal|Palermo|Palermo Viejo|
# 1                    |Argentina|Capital Federal|Palermo|
# 2       |Argentina|Capital Federal|Palermo|Palermo Soho|
# 3                    |Argentina|Capital Federal|Palermo|
# 4               |Argentina|Capital Federal|Barrio Norte|
# 5                    |Argentina|Capital Federal|Palermo|
# 6                   |Argentina|Capital Federal|Belgrano|
# 7                    |Argentina|Capital Federal|Palermo|
# 8                    |Argentina|Capital Federal|Palermo|
# 9                    |Argentina|Capital Federal|Palermo|
# 10                   |Argentina|Capital Federal|Palermo|
# 11              |Argentina|Capital Federal|Barrio Norte|
# 18961        -34.5829089,-58.4928668 -34.582909 -58.492867        448000.00
# 18962        -34.5861739,-58.5063677 -34.586174 -58.506368        148500.00
# 18963          -34.662435,-58.466795 -34.662435 -58.466795         88000.00
# 18964        -34.6650164,-58.4431386 -34.665016 -58.443139         50000.00
# 18965        -34.6579271,-58.4327115 -34.657927 -58.432712        105000.00
# 18966        -34.6651916,-58.4393973 -34.665192 -58.439397         90000.00
# 18967        -34.6601955,-58.4489907 -34.660196 -58.448991        124000.00
# 18968          -34.6633106,-58.43915 -34.663311 -58.439150         90000.00
# 18969        -34.6640573,-58.4443398 -34.664057 -58.444340        115000.00
# 18970          -34.669288,-58.443725 -34.669288 -58.443725         50000.00
# 18971          -34.669535,-58.444304 -34.669535 -58.444304         49900.00
# 18972  -34.6660551661,-58.4419339087 -34.666055 -58.441934         50000.00
# 18973           -34.66897,-58.443897 -34.668970 -58.443897         49000.00
# 18974          -34.668741,-58.443146 -34.668741 -58.443146         60000.00
# 18975           -34.66417,-58.443317 -34.664170 -58.443317         99000.00
# 18976         -34.6618136,-58.426504 -34.661814 -58.426504       3300000.00
# 18977          -34.665005,-58.443041 -34.665005 -58.443041         50433.01
# 18978          -34.664283,-58.469604 -34.664283 -58.469604         75000.00
#
#        surface_total_in_m2  surface_covered_in_m2  price_usd_per_m2  floor  \
# 0                    312.0                    NaN       6410.256410    NaN
# 1                    121.0                  121.0       6528.925620    NaN
# 2                    122.0                  108.0       2811.475410    NaN
# 3                     24.0                   24.0       6041.666667    NaN
# 4                     24.0                   24.0       7291.666667    NaN
# 5                     30.0                   30.0       4000.000000    1.0
# 6                     26.0                    NaN       3846.153846    NaN
# 7                     57.0                   57.0       6842.105263    NaN
# 8                     48.0                   48.0       2291.666667    NaN
# 9                     20.0                   20.0       2500.000000    NaN
# 10                    31.0                   31.0       7096.774194    NaN
# 11                    70.0                   70.0       2428.571429    NaN
# 12                   193.0                  176.0       1865.284974    NaN
# 13                    84.0                   84.0       2607.142857    NaN
# 14                   185.0                  185.0       3702.702703    NaN
# 15                    76.0                   76.0       3272.039474    NaN
# 16                    70.0                   70.0       9857.142857    NaN
# 17                   341.0                    NaN       5718.475073    NaN
# 18                   130.0                  120.0       2615.384615    NaN
# 19                    52.0                   48.0       4269.230769    NaN
# 20                    70.0                   70.0       2571.428571    NaN
# 21                   130.0                  130.0       3076.923077    NaN
# 22                   532.0                  334.0       2255.639098    NaN
# 23                    50.0                   50.0       5800.000000    NaN
# 24                    67.0                   64.0       4029.850746    NaN
# 25                    72.0                    NaN       3041.666667    NaN
# 26                   238.0                  238.0               NaN    NaN
# 27                   475.0                  400.0               NaN    NaN
# 28                   475.0                  400.0               NaN    NaN
# 29                    67.0                   60.0       3731.343284    NaN
# ...                    ...                    ...               ...    ...
# 18949                 62.0                   56.0       1854.838710    3.0
# 18950                130.0                   65.0        923.076923    NaN
# 18951                  NaN                   66.0               NaN    NaN
# 18952                102.0                   72.0       1557.254902    NaN
# 18953                 98.0                   90.0       1908.163265    NaN
# 18954                 50.0                   40.0       2900.000000    NaN
# 18955                 55.0                   52.0       2636.363636    NaN
# 18956                 55.0                   52.0       2636.363636    NaN
# 18957                201.0                   80.0       1447.761194    NaN
# 18958                  NaN                    NaN               NaN    NaN
# 18959                180.0                  180.0       1610.555556    NaN
# 18960                 50.0                   50.0       2300.000000    6.0
# 18961                260.0                    NaN       1723.076923    NaN
# 18962                 60.0                    NaN       2475.000000    NaN
# 18963                 55.0                   55.0       1600.000000    NaN
# 18964                 70.0                   70.0        714.285714    NaN
# 18965                  NaN                    NaN               NaN    NaN
# 18966                  NaN                    NaN               NaN    NaN
# 18967                160.0                  120.0        775.000000    NaN
# 18968                  NaN                   60.0               NaN    NaN
# 18969                120.0                  100.0        958.333333    NaN
# 18970                 75.0                   75.0        666.666667    NaN
# 18971                 75.0                   75.0        665.333333    NaN
# 18972                 72.0                   72.0        694.444444    7.0
# 18973                 75.0                   75.0        653.333333    NaN
# 18974                 55.0                   55.0       1090.909091    NaN
# 18975                115.0                   82.0        860.869565    NaN
# 18976                  NaN                 4162.0               NaN    NaN
# 18977                 45.0                   45.0       1120.733556    NaN
# 18978                 60.0                   58.0       1250.000000    9.0
#
#        rooms  expenses                                      properati_url  \
# 0        NaN       NaN  https://www.properati.com.ar/2os_venta_casa_pa...
# 1        NaN       NaN  https://www.properati.com.ar/1cl7l_venta_local...
# 2        2.0       NaN  https://www.properati.com.ar/1cm8w_venta_local...
# 3        NaN       NaN  https://www.properati.com.ar/1covk_venta_local...
# 4        NaN       NaN  https://www.properati.com.ar/1csk7_venta_local...
# 5        NaN       NaN  https://www.properati.com.ar/1cw7a_venta_local...
# 6        NaN       NaN  https://www.properati.com.ar/1d36i_venta_local...
# 7        NaN       NaN  https://www.properati.com.ar/1d3k8_venta_local...
# 8        NaN       NaN  https://www.properati.com.ar/1d5sl_venta_local...
# 9        NaN       NaN  https://www.properati.com.ar/1d86m_venta_local...
# 10       1.0    1045.0  https://www.properati.com.ar/1d8mr_venta_local...
# 11       NaN    2800.0  https://www.properati.com.ar/1dcnv_venta_local...
# 12       NaN       NaN  https://www.properati.com.ar/1dd77_venta_local...
# 13       NaN       NaN  https://www.properati.com.ar/1di5h_venta_local...
# 14       NaN       NaN  https://www.properati.com.ar/1dv8b_venta_local...
# 15       NaN       NaN  https://www.properati.com.ar/1dw79_venta_local...
# 16       NaN       NaN  https://www.properati.com.ar/1dygl_venta_local...
# 17       NaN       NaN  https://www.properati.com.ar/1dyx2_venta_local...
# 18       4.0    8000.0  https://www.properati.com.ar/1dzv6_venta_depar...
# 19       1.0       NaN  https://www.properati.com.ar/1e05k_venta_depar...
# 20       NaN    3000.0  https://www.properati.com.ar/1e0mq_venta_depar...
# 21       NaN       NaN  https://www.properati.com.ar/1e1lu_venta_local...
# 22       6.0       NaN  https://www.properati.com.ar/1e1ve_venta_casa_...
# 23       NaN       NaN  https://www.properati.com.ar/1e1wo_venta_local...
# 24       3.0    3900.0  https://www.properati.com.ar/1e1x0_venta_depar...
# 25       3.0       NaN  https://www.properati.com.ar/1e1xj_venta_ph_pa...
# 26       5.0       NaN  https://www.properati.com.ar/1e2js_venta_depar...
# 27       NaN       NaN  https://www.properati.com.ar/1e2l8_venta_casa_...
# 28       NaN       NaN  https://www.properati.com.ar/1e2ll_venta_casa_...
# 29       2.0       NaN  https://www.properati.com.ar/1e2mz_venta_depar...
# ...      ...       ...                                                ...
# 18949    3.0       NaN  https://www.properati.com.ar/1k3zz_venta_depar...
# 18950    3.0       NaN  https://www.properati.com.ar/1k401_venta_ph_vi...
# 18951    NaN    2900.0  https://www.properati.com.ar/1k4is_venta_local...
# 18952    NaN       NaN  https://www.properati.com.ar/1k4jj_venta_casa_...
# 18953    3.0       NaN  https://www.properati.com.ar/1k4n1_venta_ph_vi...
# 18954    2.0       NaN  https://www.properati.com.ar/1k4pv_venta_ph_vi...
# 18955    3.0       NaN  https://www.properati.com.ar/1k4up_venta_depar...
# 18956    3.0       NaN  https://www.properati.com.ar/1k4uq_venta_depar...
# 18957    3.0       NaN  https://www.properati.com.ar/1k6fh_venta_ph_vi...
# 18958    NaN       NaN  https://www.properati.com.ar/1k76a_venta_depar...
# 18959    4.0       NaN  https://www.properati.com.ar/1k7w1_venta_ph_vi...
# 18960    2.0       NaN  https://www.properati.com.ar/1kb1t_venta_depar...
# 18961    4.0       NaN  https://www.properati.com.ar/1kelk_venta_casa_...
# 18962    2.0       NaN  https://www.properati.com.ar/1kem4_venta_ph_vi...
# 18963    3.0       NaN  https://www.properati.com.ar/1fakt_venta_depar...
# 18964    4.0       NaN  https://www.properati.com.ar/1fnpn_venta_depar...
# 18965    NaN       NaN  https://www.properati.com.ar/1glpm_venta_casa_...
# 18966    NaN       NaN  https://www.properati.com.ar/1goie_venta_casa_...
# 18967    NaN       NaN  https://www.properati.com.ar/1grdk_venta_ph_vi...
# 18968    NaN       NaN  https://www.properati.com.ar/1hbft_venta_depar...
# 18969    3.0       NaN  https://www.properati.com.ar/1hbhx_venta_casa_...
# 18970    4.0       NaN  https://www.properati.com.ar/1hlfv_venta_depar...
# 18971    4.0       NaN  https://www.properati.com.ar/1hlg3_venta_depar...
# 18972    4.0       NaN  https://www.properati.com.ar/1ie0c_venta_depar...
# 18973    4.0       NaN  https://www.properati.com.ar/1j22x_venta_depar...
# 18974    3.0       NaN  https://www.properati.com.ar/1jcpm_venta_depar...
# 18975    3.0       NaN  https://www.properati.com.ar/1k1hs_venta_casa_...
# 18976    NaN       NaN  https://www.properati.com.ar/1k1mv_venta_local...
# 18977    3.0       NaN  https://www.properati.com.ar/1k5v0_venta_depar...
# 18978    3.0       NaN  https://www.properati.com.ar/1k5x2_venta_depar...
#
#                  barrio
# 0               PALERMO
# 1               PALERMO
# 2               PALERMO
# 3               PALERMO
# 4               PALERMO
# 5               PALERMO
# 6               PALERMO
# 7               PALERMO
# 8               PALERMO
# 9               PALERMO
# 10              PALERMO
# 11              PALERMO
# 12              PALERMO
# 13              PALERMO
# 14              PALERMO
# 15              PALERMO
# 16              PALERMO
# 17              PALERMO
# 18              PALERMO
# 19              PALERMO
# 20              PALERMO
# 21              PALERMO
# 22              PALERMO
# 23              PALERMO
# 24              PALERMO
# 25              PALERMO
# 26              PALERMO
# 27              PALERMO
# 28              PALERMO
# 29              PALERMO
# ...                 ...
# 18949  VILLA PUEYRREDON
# 18950  VILLA PUEYRREDON
# 18951  VILLA PUEYRREDON
# 18952  VILLA PUEYRREDON
# 18953  VILLA PUEYRREDON
# 18954  VILLA PUEYRREDON
# 18955  VILLA PUEYRREDON
# 18956  VILLA PUEYRREDON
# 18957  VILLA PUEYRREDON
# 18958  VILLA PUEYRREDON
# 18959  VILLA PUEYRREDON
# 18960  VILLA PUEYRREDON
# 18961  VILLA PUEYRREDON
# 18962  VILLA PUEYRREDON
# 18963     VILLA SOLDATI
# 18964     VILLA SOLDATI
# 18965     VILLA SOLDATI
# 18966     VILLA SOLDATI
# 18967     VILLA SOLDATI
# 18968     VILLA SOLDATI
# 18969     VILLA SOLDATI
# 18970     VILLA SOLDATI
# 18971     VILLA SOLDATI
# 18972     VILLA SOLDATI
# 18973     VILLA SOLDATI
# 18974     VILLA SOLDATI
# 18975     VILLA SOLDATI
# 18976     VILLA SOLDATI
# 18977     VILLA SOLDATI
# 18978     VILLA SOLDATI
#
# [18979 rows x 16 columns]

# %%
df.columns
# Out:
# Index(['created_on', 'operation', 'property_type', 'place_with_parent_names',
#        'lat-lon', 'lat', 'lon', 'price_aprox_usd', 'surface_total_in_m2',
#        'surface_covered_in_m2', 'price_usd_per_m2', 'floor', 'rooms',
#        'expenses', 'properati_url', 'barrio'],
#       dtype='object')

# %%
y = df['price_aprox_usd']

# %%
x= df[['created_on', 'operation', 'property_type', 'place_with_parent_names',
       'lat-lon', 'lat', 'lon', 'surface_total_in_m2',
       'surface_covered_in_m2', 'price_usd_per_m2', 'floor', 'rooms',
       'expenses', 'properati_url', 'barrio']]

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split( x, y, test_size=0.33, random_state=42)

# %%
x_train.shape
# Out:
# (12715, 15)

# %%
x_test.shape
# Out:
# (6264, 15)

# %%
y_train.shape
# Out:
# (12715,)

# %%
y_test.shape
# Out:
# (6264,)

# %%
x_train, x_valid, y_train, y_valid = train_test_split(x, y, test_size=0.15, random_state=42)

# %%
x_train.shape
# Out:
# (16132, 15)

# %%
x_valid.shape
# Out:
# (2847, 15)

# %%
y_train.shape
# Out:
# (16132,)

# %%
y_valid.shape
# Out:
# (2847,)
