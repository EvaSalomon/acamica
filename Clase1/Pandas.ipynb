# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('../data/marathon_results_2017.csv')

df.head()
# Out:
#    Unnamed: 0 Bib              Name  Age M/F           City State Country  \
# 0           0  11   Kirui, Geoffrey   24   M       Keringet   NaN     KEN
# 1           1  17       Rupp, Galen   30   M       Portland    OR     USA
# 2           2  23     Osako, Suguru   25   M   Machida-City   NaN     JPN
# 3           3  21  Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA
# 4           4   9    Chebet, Wilson   31   M       Marakwet   NaN     KEN
#
#   Citizen Unnamed: 9   ...         25K      30K      35K      40K     Pace  \
# 0     NaN        NaN   ...     1:16:59  1:33:01  1:48:19  2:02:53  0:04:57
# 1     NaN        NaN   ...     1:16:59  1:33:01  1:48:19  2:03:14  0:04:58
# 2     NaN        NaN   ...     1:17:00  1:33:01  1:48:31  2:03:38  0:04:59
# 3     NaN        NaN   ...     1:17:00  1:33:01  1:48:58  2:04:35  0:05:03
# 4     NaN        NaN   ...     1:16:59  1:33:01  1:48:41  2:05:00  0:05:04
#
#   Proj Time Official Time Overall Gender Division
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Bib', 'Name', 'Age', 'M/F', 'City', 'State', 'Country',
#        'Citizen', 'Unnamed: 9', '5K', '10K', '15K', '20K', 'Half', '25K',
#        '30K', '35K', '40K', 'Pace', 'Proj Time', 'Official Time', 'Overall',
#        'Gender', 'Division'],
#       dtype='object')

# %%
colnames = ['Unnamed: 0','Bib', 'Name', 'Age', 'M/F', 'City', 'State', 'Country',
       'Citizen', '5K', '10K', '15K', '20K', 'Half', '25K',
       '30K', '35K', '40K', 'Pace', 'Proj Time', 'Official Time', 'Overall', 'Gender', 'Division']

df = pd.read_csv('marathon_results_2017.csv', index_col = 0, usecols = colnames)

df.head()
# Out:
#   Bib              Name  Age M/F           City State Country Citizen  \
# 0  11   Kirui, Geoffrey   24   M       Keringet   NaN     KEN     NaN
# 1  17       Rupp, Galen   30   M       Portland    OR     USA     NaN
# 2  23     Osako, Suguru   25   M   Machida-City   NaN     JPN     NaN
# 3  21  Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA     NaN
# 4   9    Chebet, Wilson   31   M       Marakwet   NaN     KEN     NaN
#
#         5K      10K   ...         25K      30K      35K      40K     Pace  \
# 0  0:15:25  0:30:28   ...     1:16:59  1:33:01  1:48:19  2:02:53  0:04:57
# 1  0:15:24  0:30:27   ...     1:16:59  1:33:01  1:48:19  2:03:14  0:04:58
# 2  0:15:25  0:30:29   ...     1:17:00  1:33:01  1:48:31  2:03:38  0:04:59
# 3  0:15:25  0:30:29   ...     1:17:00  1:33:01  1:48:58  2:04:35  0:05:03
# 4  0:15:25  0:30:28   ...     1:16:59  1:33:01  1:48:41  2:05:00  0:05:04
#
#   Proj Time Official Time Overall Gender Division
# ...

# %%
df.head().T
# Out:
#                              0            1              2                 3  \
# Bib                         11           17             23                21
# Name           Kirui, Geoffrey  Rupp, Galen  Osako, Suguru  Biwott, Shadrack
# Age                         24           30             25                32
# M/F                          M            M              M                 M
# City                  Keringet     Portland   Machida-City     Mammoth Lakes
# State                      NaN           OR            NaN                CA
# Country                    KEN          USA            JPN               USA
# Citizen                    NaN          NaN            NaN               NaN
# 5K                     0:15:25      0:15:24        0:15:25           0:15:25
# 10K                    0:30:28      0:30:27        0:30:29           0:30:29
# 15K                    0:45:44      0:45:44        0:45:44           0:45:44
# ...

# %%
df.iloc[:, 8:20] = df.iloc[:, 8:20].apply(pd.to_timedelta)

df.dtypes
# Out:
# Bib                       object
# Name                      object
# Age                        int64
# M/F                       object
# City                      object
# State                     object
# Country                   object
# Citizen                   object
# 5K               timedelta64[ns]
# 10K              timedelta64[ns]
# 15K              timedelta64[ns]
# 20K              timedelta64[ns]
# Half             timedelta64[ns]
# 25K              timedelta64[ns]
# 30K              timedelta64[ns]
# 35K              timedelta64[ns]
# 40K              timedelta64[ns]
# Pace             timedelta64[ns]
# Proj Time        timedelta64[ns]
# Official Time    timedelta64[ns]
# Overall                    int64
# Gender                     int64
# Division                   int64
# dtype: object

# %% [markdown]
# ###Para saber la cantidad de valores nulos por columna

# %%
df.isnull().sum()
# Out:
# Bib                  0
# Name                 0
# Age                  0
# M/F                  0
# City                 0
# State             3595
# Country              0
# Citizen          25156
# 5K                   0
# 10K                  0
# 15K                  0
# 20K                  0
# Half                 0
# 25K                  0
# 30K                  0
# 35K                  0
# 40K                  0
# Pace                 0
# Proj Time            0
# Official Time        0
# Overall              0
# Gender               0
# Division             0
# dtype: int64

# %%
df.shape
# Out:
# (26410, 23)

# %%
df['Citizen'].value_counts()
# Out:
# GBR    141
# CAN    131
# JPN    115
# CHN     78
# USA     74
# IRL     72
# MEX     69
# FRA     50
# GER     46
# AUS     35
# ESP     27
# NED     25
# VEN     20
# IND     19
# NZL     17
# POL     17
# ARG     15
# ITA     15
# KOR     13
# RSA     13
# BRA     13
# PHI     13
# BEL     12
# COL     12
# DOM     10
# SUI     10
# SWE     10
# CRC     10
# DEN     10
# POR      9
#       ...
# TRI      2
# SLO      2
# NGR      2
# INA      2
# THA      2
# PAK      2
# MAR      2
# BUL      2
# BLR      1
# MOZ      1
# ALB      1
# BAN      1
# LAT      1
# CAM      1
# SRB      1
# ETH      1
# SRI      1
# JAM      1
# NAM      1
# EGY      1
# BIH      1
# LIB      1
# ZAM      1
# KEN      1
# CAF      1
# HON      1
# CUB      1
# TUN      1
# ZIM      1
# AZE      1
# Name: Citizen, Length: 85, dtype: int64

# %%
df.Gender.unique()
# Out:
# array([    1,     2,     3, ..., 14436, 14437, 14438])

# %%
df.loc[df.Age > 75]
# Out:
#        Unnamed: 0    Bib                     Name  Age M/F  \
# 9715         9715  18789  Barreneche-Rios, Hernan   77   M
# 16338       16338  21593           Susumu, Ichida   79   M
# 16557       16557  24437         Pain, Malcolm A.   79   M
# 16838       16838  12476           Ouweleen, John   76   M
# 17843       17843  24462           Seamon, Walter   76   M
# 18361       18361  24861        Kasamatsu, Takuji   78   M
# 18476       18476  21517      Cerminaro, Tony Sr.   80   M
# 19507       19507  22852      Burgasser, Joseph M   78   M
# 21121       21121  25038          Kono, Michimasa   76   M
# 21363       21363  25095         Miller, Gerald W   80   M
# 21983       21983  25123      Shimojou, Michiharu   81   M
# 22619       22619  25134                Yoo, Jack   83   M
# 23325       23325  25089              Tomek, Ivan   77   M
# 23413       23413  24818       Bobeldijk, Volkert   80   M
# 23490       23490  24654            Smith, Dallas   76   M
# ...

# %%
df['Age'].plot(kind = 'hist', bins = 30, figsize=(15,8))

# %%
df['Age'].plot(kind = 'box', figsize=(15,8))
